# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](mlcourse.ai) – Open Machine Learning Course
# Author: Arina Lopukhova (@erynn). Edited by [Yury Kashnitskiy](https://yorko.github.io) (@yorko). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# <h1><center>Assignment #1. Fall 2018</center></h1>
# <h2><center>Exploratory data analysis of Olympic games with Pandas</center></h2>

# %% [markdown]
# __There are ten questions about [120 years of Olympic history: athletes and results](https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results/version/2) dataset in this task. Your task is to fill in the missing Python code and choose answers in [this web-form](https://docs.google.com/forms/d/179HYvlF_0x435CWdu2aOtR9a3flh0YCQXXNXhXaKw2M).__

# %% [markdown]
# Download the file `athlete_events.csv` from [Kaggle page](https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results). The dataset has the following features (copied from Kaggle):
#
# - __ID__ - Unique number for each athlete
# - __Name__ - Athlete's name
# - __Sex__ - M or F
# - __Age__ - Integer
# - __Height__ - In centimeters
# - __Weight__ - In kilograms
# - __Team__ - Team name
# - __NOC__ - National Olympic Committee 3-letter code
# - __Games__ - Year and season
# - __Year__ - Integer
# - __Season__ - Summer or Winter
# - __City__ - Host city
# - __Sport__ - Sport
# - __Event__ - Event
# - __Medal__ - Gold, Silver, Bronze, or NA

# %%
import pandas as pd

# %%
# Change the path to the dataset file if needed. 
PATH = '../data/athlete_events.csv'

# %%
data = pd.read_csv(PATH)
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data.shape
# Out:
# (271116, 15)

# %%
data['ID'].nunique()
# Out:
# 135571

# %%
data.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %% [markdown]
# __1. How old were the youngest male and female participants of the 1996 Olympics?__
#
# - 16 and 15
# - 14 and 12
# - 16 and 12
# - 13 and 11

# %% [markdown]
# ## Відповідь:

# %% [markdown]
# - 14 and 12

# %%
data[data['Year']==1996].shape
# Out:
# (13780, 15)

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data[(data['Year']==1996)&(data['Sex']=='F')]
# Out:
#             ID                                        Name Sex   Age  Height  \
# 32          13                          Minna Maarit Aalto   F  30.0   159.0
# 105         37                          Ann Kristin Aarnes   F  23.0   182.0
# 280        147                               Joanne Abbott   F  41.0   160.0
# 579        332                            Zarinah Abdullah   F  25.0     NaN
# 719        410                     Edwige Marie Abna Fouda   F  23.0   173.0
# 874        504                            Cheryl Abplanalp   F  24.0   174.0
# 900        512             Shiny Kurisingal Abraham-Wilson   F  31.0   167.0
# 958        537                          Ek'aterina Abramia   F  16.0   167.0
# 1127       630                         Anna Accensi Abella   F  26.0     NaN
# 1312       737           Amelia Lynn "Amy" Acuff (-Harvey)   F  21.0   188.0
# 1475       820                      Judith C. "Judi" Adams   F  37.0     NaN
# ...

# %%
# You code here 
data[(data['Sex'] == 'M') & (data['Games'] == '1996 Summer')]['Age'].min(), data[(data['Sex'] == 'F') & (data['Games'] == '1996 Summer')]['Age'].min()
# Out:
# (14.0, 12.0)

# %% [markdown]
# __2. What was the percentage of male gymnasts among all the male participants of the 2000 Olympics? Round the answer to the first decimal.__
#
# *Hint:* here and further if needed drop duplicated sportsmen to count only unique ones.
#
# - 0.2
# - 1.5
# - 2.5
# - 7.7

# %% [markdown]
# 1.5

# %%
data[(data['Year']==2000)&(data['Sex']=='M')].shape
# Out:
# (8390, 15)

# %%
data[(data['Year']==2000)&(data['Sex']=='M')].nunique()
# Out:
# ID        6579
# Name      6576
# Sex          1
# Age         43
# Height      73
# Weight     134
# Team       236
# NOC        200
# Games        1
# Year         1
# Season       1
# City         1
# Sport       31
# Event      180
# Medal        3
# dtype: int64

# %%
# You code here 

round(float(data[(data['Sport']=='Gymnastics') & (data['Sex'] == 'M') & (data['Games'] == '2000 Summer')]['Name'].nunique())/
      float(data[(data['Sex'] == 'M') & (data['Games'] == '2000 Summer')]['Name'].nunique())*100, 1)
# Out:
# 1.5

# %% [markdown]
# __3. What are the mean and standard deviation of height for female basketball players participated in the 2000 Olympics? Round the answer to the first decimal.__
#
# - 178.5 and 7.2
# - 179.4 and 10
# - 180.7 and 6.7
# - 182.4 and 9.1

# %% [markdown]
# 182.4 and 9.1

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
data['Height'].std()
# Out:
# 10.518462222678274

# %%
from matplotlib import pyplot as plt

# %%
data['Height'].hist(bins=100)
plt.show()

# %%
# You code here 
data[(data['Sex']=='F') & (data['Sport']=='Basketball') & (data['Games'] == '2000 Summer')]['Height'].describe()
# Out:
# count    142.000000
# mean     182.387324
# std        9.139462
# min      162.000000
# 25%      175.000000
# 50%      182.000000
# 75%      190.000000
# max      213.000000
# Name: Height, dtype: float64

# %% [markdown]
# __4. Find a sportsperson participated in the 2002 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?__
#
# - Judo
# - Bobsleigh
# - Weightlifting
# - Boxing

# %% [markdown]
# Bobsleigh

# %%
data[data['Year']==2002]['Weight'].head()
# Out:
# 28    96.0
# 72    85.0
# 73    85.0
# 74    85.0
# 75    85.0
# Name: Weight, dtype: float64

# %%
data[data['Games'] == '2002 Winter']['Weight'].describe()
# Out:
# count    4062.000000
# mean       71.197070
# std        13.257178
# min        42.000000
# 25%        61.000000
# 50%        69.000000
# 75%        80.000000
# max       123.000000
# Name: Weight, dtype: float64

# %%
# You code here 
data[data['Games'] == '2002 Winter']['Weight'].describe()
data[(data['Games'] == '2002 Winter') & (data['Weight'] == 123)]
# Out:
#           ID               Name Sex   Age  Height  Weight    Team  NOC  \
# 99154  50171  Emmanuel Hostache   M  26.0   190.0   123.0  France  FRA
#
#              Games  Year  Season            City      Sport  \
# 99154  2002 Winter  2002  Winter  Salt Lake City  Bobsleigh
#
#                      Event Medal
# 99154  Bobsleigh Men's Two   NaN

# %% [markdown]
# __5. How many times did Pawe Abratkiewicz participate in the Olympics held in different years?__
#
# - 0
# - 1
# - 2
# - 3

# %% [markdown]
# 3

# %%
data[data['Name']=='']
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# You code here 
data[data['Name'] == 'Pawe Abratkiewicz']['Games'].nunique()
# Out:
# 3

# %% [markdown]
# __6. How many silver medals in tennis did Australia win at the 2000 Olympics?__
#
# - 0
# - 1
# - 2
# - 3

# %% [markdown]
# 2

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# You code here 
data[(data['Sport']=='Tennis') & (data['Games'] == '2000 Summer') & (data['Medal'] =='Silver') & (data['Team'] == 'Australia')]
# Out:
#             ID                    Name Sex   Age  Height  Weight       Team  \
# 262820  131504  Todd Andrew Woodbridge   M  29.0   178.0    75.0  Australia
# 262831  131511  Mark Raymond Woodforde   M  34.0   183.0    80.0  Australia
#
#         NOC        Games  Year  Season    City   Sport                 Event  \
# 262820  AUS  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Men's Doubles
# 262831  AUS  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Men's Doubles
#
#          Medal
# 262820  Silver
# 262831  Silver

# %% [markdown]
# __7. Is it true that Switzerland won fewer medals than Serbia at the 2016 Olympics? Do not consider NaN values in _Medal_ column.__
#
# - Yes
# - No

# %% [markdown]
# Yes

# %%
data[(data['Year']==2016)& (data['Team']=='Serbia')].dropna().count()
# Out:
# ID        54
# Name      54
# Sex       54
# Age       54
# Height    54
# Weight    54
# Team      54
# NOC       54
# Games     54
# Year      54
# Season    54
# City      54
# Sport     54
# Event     54
# Medal     54
# dtype: int64

# %%
data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# You code here 
ds = data[(data['Team'].isin(['Serbia', 'Switzerland'])) & 
          (data['Games'] =='2016 Summer') & 
          (data['Medal'].isin(['Gold', 'Silver', 'Bronze']))]

# %%
ds.groupby('Team')['Medal'].describe()
# Out:
#             count unique     top freq
# Team
# Serbia         54      3  Silver   27
# Switzerland    11      3    Gold    6

# %% [markdown]
# __8. What age category did the fewest and the most participants of the 2014 Olympics belong to?__
# - [45-55] and [25-35) correspondingly
# - [45-55] and [15-25) correspondingly
# - [35-45] and [25-35) correspondingly
# - [45-55] and [35-45) correspondingly

# %% [markdown]
# [45-55] and [25-35) correspondingly

# %%
# You code here 
data[(data['Year']==2014) & (data['Age']>=45) & (data['Age']<=55)]['Name'].nunique(), data[(data['Year']==2014) & (data['Age']>=25) & (data['Age']<=35)]['Name'].nunique(),data[(data['Year']==2014) & (data['Age']>=15) & (data['Age']<=25)]['Name'].nunique(),data[(data['Year']==2014) & (data['Age']>=35) & (data['Age']<=45)]['Name'].nunique()
# Out:
# (5, 1447, 1394, 151)

# %% [markdown]
# __9. Is it true that there were Summer Olympics held in Lake Placid? Is it true that there were Winter Olympics held in Sankt Moritz?__
#
# - Yes, Yes
# - Yes, No
# - No, Yes
# - No, No

# %% [markdown]
# No, Yes

# %%
# You code here 
data[(data['Season'] == 'Summer') & (data['City'].str.startswith('Lake Placid'))]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
data[(data['Season'] == 'Winter') & (data['City'].str.startswith('Sankt Moritz'))]
# Out:
#             ID                               Name Sex   Age  Height  Weight  \
# 935        529    Karl Gustaf Emanuel Abrahamsson   M  31.0     NaN     NaN
# 1187       665              Gilbert Achard-Picard   M  29.0     NaN     NaN
# 1439       802             Tadeusz Ralf Adamowski   M  26.0   177.0    70.0
# 1454       810  Bridget Shirley Adams (-Bengough)   F  19.0     NaN     NaN
# 2707      1508                     Enrico Airoldi   M  24.0     NaN     NaN
# ...        ...                                ...  ..   ...     ...     ...
# 270713  135383           Annelore Zckert (-Zrost)   F  22.0     NaN     NaN
# 270714  135383           Annelore Zckert (-Zrost)   F  22.0     NaN     NaN
# 270863  135463                    Hans Zurbriggen   M  27.0     NaN     NaN
# 270881  135466                  Robert Zurbriggen   M  30.0     NaN     NaN
# 270882  135466                  Robert Zurbriggen   M  30.0     NaN     NaN
#
# ...

# %% [markdown]
# __10. What is the absolute difference between the number of unique sports at the 1995 Olympics and 2016 Olympics?__
#
# - 16
# - 24
# - 26
# - 34

# %% [markdown]
# 34

# %%
# You code here 
data[(data['Year'] == 1995)]['Sport'].nunique(), data[(data['Year'] == 2016)]['Sport'].nunique()
# Out:
# (0, 34)
